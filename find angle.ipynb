# %% [markdown]
# <a href="https://colab.research.google.com/github/Alok1721/opencv/blob/main/find%20angle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find the angle(Project)
#
# ```
# #
# ```

# %%
import cv2
import numpy
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("image1.jpg")
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)

contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-22a1648da895> in <cell line: 2>()
#       1 img=cv2.imread("image1.jpg")
# ----> 2 g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 _, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)
#       4
#       5 contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# #Contour Method
#
# ```
# # this is not working as i need
#
# ```

# %%
for contour in contours:
    M = cv2.moments(contour)
    if M["m00"] != 0:
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
        cv2.circle(img, (cX, cY), 5, (255, 0, 0), -1)
height, width, _ = img.shape
cv2.line(img, (cX, cY), (width, height//2), (0, 0, 255), 2)


cv2_imshow(img)
key = cv2.waitKey(0)
if key == ord('q'):
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("Image-1.jpg")
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)

contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
for contour in contours:
    M = cv2.moments(contour)
    if M["m00"] != 0:
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
        cv2.circle(img, (cX, cY), 5, (255, 0, 0), -1)
height, width, _ = img.shape
cv2.line(img, (cX, cY), (width, height//2), (0, 0, 255), 2)


# Iterate over contours and find minimum area rectangle
for contour in contours:
    # Get the minimum area rectangle
    rect = cv2.minAreaRect(contour)

    # Convert rectangle to box (four corners)
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # Draw the box (rectangle) around the contour
    cv2.drawContours(img, [box], 0, (0, 255, 0), 2)

    # Draw red circles at the four corners of the rectangle
    for point in box:
        cv2.circle(img, tuple(point), 5, (0, 0, 255), -1)

# Display the image with the rectangle and corner circles
cv2_imshow(img)
key = cv2.waitKey(0)

if key == ord('q'):
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1190x630>

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

img = cv2.imread("s6.png")
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)

contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate over contours and find minimum area rectangle
for contour in contours:
    # Get the minimum area rectangle
    rect = cv2.minAreaRect(contour)

    # Convert rectangle to box (four corners)
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # Draw the box (rectangle) around the contour
    cv2.drawContours(img, [box], 0, (0, 255, 0), 2)

    # Draw a red circle only at the bottom-right corner of the rectangle
    bottom_right_point = tuple(box[3])
    top_right_point=tuple(box[2])
    h, w, _ = img.shape
    cv2.circle(img, bottom_right_point, 5, (0, 0, 255), -1)
    cv2.line(img,top_right_point,bottom_right_point,(0,0,255),2)
    x_b, y_b = bottom_right_point
    x_t, y_t =top_right_point
# cv2.line(img,bottom_right_point,(width,y_coordinate),(0,0,255),2)
vector1=(x_t-int(w/2),y_t-int(h/2))
vector2=(int(w)-x_b,int(h/2)-y_b)
angle_radians = math.atan2(vector2[1], vector2[0]) - math.atan2(vector1[1], vector1[0])
angle_degrees = math.degrees(angle_radians)
angle_degrees = (angle_degrees + 360) % 360

# angle_rad = np.arctan2(top_right_point[1]-bottom_right_point[1] , width - top_right_point[0])
# angle_deg = np.degrees(angle_rad)


cv2.putText(img, "angle:"+str(int(angle_degrees)), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)


# Display the image with the rectangle and the bottom-right corner circle
cv2_imshow(img)
key = cv2.waitKey(0)

if key == ord('q'):
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=189x267>

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

img = cv2.imread("image2.jpg")
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)

contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate over contours and find minimum area rectangle
for contour in contours:
    # Get the minimum area rectangle
    rect = cv2.minAreaRect(contour)

    # Convert rectangle to box (four corners)
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # Draw the box (rectangle) around the contour
    cv2.drawContours(img, [box], 0, (0, 255, 0), 2)

    # Draw a red circle only at the bottom-right corner of the rectangle
    bottom_right_point = tuple(box[3])
    top_right_point = tuple(box[2])
    h, w, _ = img.shape
    cv2.circle(img, bottom_right_point, 5, (0, 0, 255), -1)

    x_b, y_b = bottom_right_point
    x_t, y_t = top_right_point
    distance = math.sqrt((x_b - x_t)**2 + (y_b - y_t)**2)

    p_distance = abs(y_t - int(h/2))  # Corrected calculation of p_distance

    print("l, p:", distance, p_distance)

if distance > 0:  # Check if the distance is greater than 0 before calculating the angle
    angle_radians = math.asin(min(p_distance / distance, 1.0))  # Ensure the value is in the valid range [-1, 1]
    angle_degrees = math.degrees(angle_radians)
    print("angle:", angle_degrees)

    cv2.putText(img, "angle:" + str(int(angle_degrees)), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with the rectangle and the bottom-right corner circle
cv2_imshow(img)
key = cv2.waitKey(0)

if key == ord('q'):
    cv2.destroyAllWindows()
# Out:
# l, p: 0.0 286
# l, p: 61.84658438426491 282
# angle: 90.0
# <PIL.Image.Image image mode=RGB size=1043x723>

# %% [markdown]
# # coordinate method
#
# ```
# # this is working fine with adjustment
#
# ```

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

img = cv2.imread("Image-1.jpg")
g_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(g_img, 127, 255, cv2.THRESH_BINARY_INV)

contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

bottom_right_point=0
bottom_left_point=0
top_left_point=0
top_right_point=0
# Iterate over contours and find minimum area rectangle
for contour in contours:
    # Get the minimum area rectangle
    rect = cv2.minAreaRect(contour)

    # Convert rectangle to box (four corners)
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # Draw the box (rectangle) around the contour
    cv2.drawContours(img, [box], 0, (0, 255, 0), 2)

    # Draw a red circle only at the bottom-right corner of the rectangle
    bottom_right_point = tuple(box[3])
    top_right_point = tuple(box[2])
    top_left_point = tuple(box[1])
    bottom_left_point = tuple(box[0])
    # print(tuple(box))

h, w, _ = img.shape



    #cv2.circle(img,(x_b,y_b), 5, (0, 0, 255), -1)

#assiging the coordinate for checking

x_b2, y_b2 = bottom_right_point
x_b1,y_b1=bottom_left_point
x_t1,y_t1=top_left_point

x_t2, y_t2 = top_right_point

x_b,y_b= (x_b1+x_b2)//2 ,(y_b1+y_b2)//2
x_t,y_t=(x_t1+x_t2)//2,(y_t1+y_t2)//2
print("centre point :",x_b,y_b,y_t,y_b)
print("bottom right:",bottom_right_point)
print("bottom left:",bottom_left_point)
print("top right:",top_right_point)
print("top left:",top_left_point)
cv2.circle(img, (x_b,y_b), 5, (0, 0, 255), -1)
cv2.circle(img, (x_t,y_t), 5, (0, 0, 255), -1)
distance = math.sqrt((x_b - x_t)**2 + (y_b - y_t)**2)

p_distance = y_b-y_t  # Corrected calculation of p_distance

print("l, p:", distance, p_distance)

if distance > 0:  # Check if the distance is greater than 0 before calculating the angle
    angle_radians = math.asin(min(p_distance / distance, 1.0))  # Ensure the value is in the valid range [-1, 1]
    angle_degrees = math.degrees(angle_radians)
    print("angle:", angle_degrees)

cv2.putText(img, "angle:" + str(int(angle_degrees)), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with the rectangle and the bottom-right corner circle
cv2_imshow(img)
key = cv2.waitKey(0)

if key == ord('q'):
    cv2.destroyAllWindows()
# Out:
# centre point : 129 455 167 455
# bottom right: (138, 485)
# bottom left: (120, 426)
# top right: (1080, 197)
# top left: (1062, 138)
# l, p: 985.0421310786661 288
# angle: 17.00009445363876
# <PIL.Image.Image image mode=RGB size=1190x630>

# %% [markdown]
# #Hough Transform
#
# ```
# # final submission
# ```

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread("image3.png")

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply edge detection (optional)
edges = cv2.Canny(gray, 50, 150)

# Apply Hough Line Transform
lines = cv2.HoughLines(edges, 1, np.pi / 180, threshold=100)
print("lines are:",lines)
# Iterate through each line and calculate the angle with respect to the horizontal axis
for line in lines:
    rho, theta = line[0]
    angle = math.degrees(theta)

    # Calculate angle with respect to the horizontal axis
    horizontal_angle = (angle - 90)*-1  # Adjust the calculation here

    # Print or use the angle as needed
    print("Angle with respect to horizontal axis:", horizontal_angle)

    # Draw the line on the image (optional)
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho
    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))
cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)

    # Display the angle on the image
cv2.putText(img, f"Angle: {horizontal_angle} degrees", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the result (optional)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# lines are: [[[345.           0.94247776]]
#
#  [[311.           0.94247776]]
#
#  [[312.           0.9250245 ]]]
# Angle with respect to horizontal axis: 36.00000191240768
# Angle with respect to horizontal axis: 36.00000191240768
# Angle with respect to horizontal axis: 36.9999996635055
# <PIL.Image.Image image mode=RGB size=539x466>

# %% [markdown]
# ## modification of Hough transform

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread("image2.jpg")

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply edge detection (optional)
edges = cv2.Canny(gray, 50, 150)

# Apply Probabilistic Hough Line Transform
lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)
print("lines are:", lines)

# Iterate through each line and calculate the angle with respect to the horizontal axis
for line in lines:
    x1, y1, x2, y2 = line[0]
    angle_rad = np.arctan2(y2 - y1, x2 - x1)
    angle_deg = np.degrees(angle_rad)

    # Calculate angle with respect to the horizontal axis
    horizontal_angle = (angle_deg ) * -1  # Adjust the calculation here

    # Print or use the angle as needed
print("Angle with respect to horizontal axis:", horizontal_angle)

    # Draw the line on the image (optional)
cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)

    # Display the angle on the image
cv2.putText(img, f"Angle: {horizontal_angle} degrees", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the result (optional)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# lines are: [[[302 214 744 571]]
#
#  [[606 381 932 645]]
#
#  [[414 227 856 584]]
#
#  [[166  28 412 227]]
#
#  [[587 443 895 692]]
#
#  [[138  82 587 445]]
#
#  [[128  75 326 235]]
#
#  [[168  29 601 379]]
#
#  [[501 374 856 661]]]
# Angle with respect to horizontal axis: -38.95383122656365
# <PIL.Image.Image image mode=RGB size=1043x723>
